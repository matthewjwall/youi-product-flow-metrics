# %% [markdown]
# # Product Flow Report - Data

# %%
#from scripts import youi_utils
from scripts import youi
import importlib
import pandas as pd
import datetime as dt

importlib.reload(youi)

#youi.get_pm_issues()
# Out:
# <module 'scripts.youi' from 'C:\\Users\\Matt\\Documents\\dx\\product_metrics\\youi-product-flow-007\\scripts\\youi.py'>

# %%
youi.pm_children_changelog('pm_jira_2019-08-23.csv')
# Out:
# No related issues
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Miniconda3\envs\tfdx\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-8545db9c4007> in <module>
# ----> 1 youi.pm_children_changelog('pm_jira_2019-08-23.csv')
#
# ~\Documents\dx\product_metrics\youi-product-flow-007\scripts\youi.py in pm_children_changelog(pm_csv)
# ...

# %%
pd.read_csv('pm_changelog.csv', names= ['remove', 'pm_key', 'pm_id', 'related_key', 'related_id', 'related_type', 'updated', 'status'])
# Out:
#      remove  pm_key  pm_id related_key  related_id related_type  \
# 0         0  PM-167  77041       RN-72       73254        Story
# 1         0  PM-167  77041       RN-72       73254        Story
# 2         0  PM-157  85448       RN-73       73255        Story
# 3         0  PM-157  85448       RN-73       73255        Story
# 4         0  PM-157  85448       RN-73       73255        Story
# ..      ...     ...    ...         ...         ...          ...
# 902       0    PM-4  80194     KS-1805       84416        Story
# 903       0    PM-4  80194     KS-1805       84416        Story
# 904       0    PM-4  80194     KS-1805       84416        Story
# 905       0    PM-4  80194     KS-1805       84416        Story
# 906       0    PM-4  80194     KS-1805       84416        Story
#
#                           updated         status
# 0    2018-01-25T12:42:11.239-0500        Blocked
# 1    2018-01-25T11:13:46.183-0500    In Progress
# ...
